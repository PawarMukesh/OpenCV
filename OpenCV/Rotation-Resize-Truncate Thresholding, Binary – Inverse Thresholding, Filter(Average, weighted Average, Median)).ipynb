# %% [markdown]
# # 1. Import Library

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %% [markdown]
# # 2. Read Image

# %%
image = cv2.imread('/content/pexels-photo-1996333.jpeg')

# %% [markdown]
# # 3. Show Image

# %%
cv2_imshow(image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 4. Print an Image

# %%
print(image)
# Out:
# [[[30 19 15]
#   [30 19 15]
#   [30 19 15]
#   ...
#   [33 34 32]
#   [33 30 26]
#   [29 26 21]]
#
#  [[30 19 15]
#   [30 19 15]
#   [30 19 15]
#   ...
#   [36 35 31]
#   [34 31 26]
#   [32 30 22]]
#
#  [[30 19 15]
#   [30 19 15]
#   [30 19 15]
#   ...
#   [36 36 30]
#   [37 35 27]
#   [37 35 25]]
#
#  ...
#
#  [[49 52 50]
#   [39 42 40]
#   [33 37 32]
#   ...
#   [31 30 16]
#   [28 28 14]
#   [27 27 13]]
#
#  [[43 45 39]
#   [38 40 34]
#   [35 36 27]
#   ...
#   [30 29 15]
#   [28 28 16]
#   [27 27 15]]
#
#  [[31 34 25]
#   [34 37 28]
#   [41 40 30]
#   ...
#   [31 30 16]
#   [29 28 18]
#   [30 29 19]]]

# %% [markdown]
# # 5. Find Height & Width

# %%
height, width = image.shape[:2]
print("Height:", height)
print("Width:", width)
# Out:
# Height: 2334
# Width: 3502

# %% [markdown]
# # 6. Rotate an Image with Angle 160

# %%
# Define the angle
angle = 160

# Define the rotation matrix
rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)

# Apply the rotation to the image
rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))

# Show the image
cv2_imshow(rotated_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 7. Resize The Image

# %%
resized_image = cv2.resize(image, (width // 2, height // 2))
cv2_imshow(resized_image)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Check orignal shape and resized image shape
print("Original Image Shape",image.shape[:2])
print("Resized Image Shape", resized_image.shape[:2])
# Out:
# Original Image Shape (2334, 3502)
# Resized Image Shape (1167, 1751)

# %% [markdown]
# # 8. Apply Truncate Thresholding, Binary – Inverse Thresholding

# %%
# Convert image into gray scale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply thresholding
_, binary_inverse_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_TRUNC)

# Display the image
cv2_imshow(binary_inverse_image)
# Out:
# <PIL.Image.Image image mode=L size=3502x2334>

# %% [markdown]
# # 9. Perform Power Law Transformation using inverse Gamma

# %%
gamma = 0.5
gamma_corrected = np.uint8(np.power(gray_image / 255.0, gamma) * 255)
cv2_imshow(gamma_corrected)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 10. Apply Average Filter

# %%
average_filtered = cv2.blur(image, (5, 5))
cv2_imshow(average_filtered)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 11. Apply Weighted-Average Filter

# %%
weighted_average_filtered = cv2.GaussianBlur(image, (5, 5), 0)
cv2_imshow(weighted_average_filtered)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # 12. Apply Median Filter

# %%
median_filtered = cv2.medianBlur(image, 5)
cv2_imshow(median_filtered)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
